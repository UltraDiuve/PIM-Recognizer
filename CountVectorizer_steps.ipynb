# %% [markdown]
# # Récapitulatif sur les notions dans countvectorizer

# %% [markdown]
# ![CountVectorizer%20steps%20%282%29.png](attachment:CountVectorizer%20steps%20%282%29.png)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vect = CountVectorizer(ngram_range=(1,2), stop_words=['de'], strip_accents='unicode')

# %%
count_vect
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 2), preprocessor=None, stop_words=['de'],
#                 strip_accents='unicode', token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
text = "une pâte de fruit jolie qui plait de famille"

# %%
count_vect.fit_transform([text])
# Out:
# <1x13 sparse matrix of type '<class 'numpy.int64'>'
# 	with 13 stored elements in Compressed Sparse Row format>

# %%
count_vect.vocabulary_
# Out:
# {'une': 11,
#  'pate': 5,
#  'fruit': 1,
#  'jolie': 3,
#  'qui': 9,
#  'plait': 7,
#  'famille': 0,
#  'une pate': 12,
#  'pate fruit': 6,
#  'fruit jolie': 2,
#  'jolie qui': 4,
#  'qui plait': 10,
#  'plait famille': 8}

# %%
count_vect.stop_words
# Out:
# ['de']

# %%
count_vect.build_preprocessor()
# Out:
# functools.partial(<function _preprocess at 0x000002366AAB1828>, accent_function=<function strip_accents_unicode at 0x0000023669B228B8>, lower=True)

# %%
count_vect.build_preprocessor()('Yo ma bitch TU Kiff$e les âccents dé âëklë')
# Out:
# 'yo ma bitch tu kiff$e les accents de aekle'

# %%
count_vect.build_tokenizer()(count_vect.build_preprocessor()('Yo ma bitch TU Kiff$es les âccents de âëklë'))
# Out:
# ['yo', 'ma', 'bitch', 'tu', 'kiff', 'es', 'les', 'accents', 'de', 'aekle']

# %%
count_vect = CountVectorizer(ngram_range=(1,2), stop_words=['de'], strip_accents='unicode').fit(['eke', 'ds', 'de'])

# %%
count_vect.stop_words
# Out:
# ['de']

# %%
text = 'Yo ma bitch TU Kiff$es les âccents de âëklë'

# %%
count_vect = CountVectorizer(ngram_range=(1,2), stop_words=['de'], strip_accents='unicode')
count_vect2 = CountVectorizer(ngram_range=(1,2), stop_words=['de'], strip_accents='unicode')
count_vect2.fit(['zkelfd fdsjkfd zalfdks', 'fd sjk de zeklcsm'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 2), preprocessor=None, stop_words=['de'],
#                 strip_accents='unicode', token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
prepro_non_fit = count_vect.build_preprocessor()
token_non_fit = count_vect.build_tokenizer()
anal_non_fit = count_vect.build_analyzer()
prepro_fit = count_vect2.build_preprocessor()
token_fit = count_vect2.build_tokenizer()
anal_fit = count_vect2.build_analyzer()

# %%
prepro_non_fit(text)
# Out:
# 'yo ma bitch tu kiff$es les accents de aekle'

# %%
prepro_fit(text)
# Out:
# 'yo ma bitch tu kiff$es les accents de aekle'

# %%
token_non_fit(text)
# Out:
# ['Yo', 'ma', 'bitch', 'TU', 'Kiff', 'es', 'les', 'âccents', 'de', 'âëklë']

# %%
token_fit(text)
# Out:
# ['Yo', 'ma', 'bitch', 'TU', 'Kiff', 'es', 'les', 'âccents', 'de', 'âëklë']

# %%
anal_non_fit(text)
# Out:
# ['yo',
#  'ma',
#  'bitch',
#  'tu',
#  'kiff',
#  'es',
#  'les',
#  'accents',
#  'aekle',
#  'yo ma',
#  'ma bitch',
#  'bitch tu',
#  'tu kiff',
#  'kiff es',
#  'es les',
#  'les accents',
#  'accents aekle']

# %%
anal_fit(text)
# Out:
# ['yo',
#  'ma',
#  'bitch',
#  'tu',
#  'kiff',
#  'es',
#  'les',
#  'accents',
#  'aekle',
#  'yo ma',
#  'ma bitch',
#  'bitch tu',
#  'tu kiff',
#  'kiff es',
#  'es les',
#  'les accents',
#  'accents aekle']

# %%
token_non_fit
# Out:
# <function Pattern.findall(string, pos=0, endpos=9223372036854775807)>

# %%
count_vect3 = CountVectorizer(ngram_range=(1,2), strip_accents='unicode', max_df=2)
count_vect3
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=2, max_features=None, min_df=1,
#                 ngram_range=(1, 2), preprocessor=None, stop_words=None,
#                 strip_accents='unicode', token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
count_vect3.fit(['djk dlsja ndskls fsjk de', 'fsdklds zlzfio de alksqn', 'ala apvsoijf aioa DE jaka'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=2, max_features=None, min_df=1,
#                 ngram_range=(1, 2), preprocessor=None, stop_words=None,
#                 strip_accents='unicode', token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
count_vect3.stop_words_
# Out:
# {'de'}

# %%
count_vect3.get_stop_words()

# %%
token = count_vect3.build_tokenizer()
anal = count_vect3.build_analyzer()
prepro = count_vect3.build_preprocessor()

# %%
token('alsd fdsqkl de aklz')
# Out:
# ['alsd', 'fdsqkl', 'de', 'aklz']

# %%
anal('alsd fdsqkl de aklz')
# Out:
# ['alsd', 'fdsqkl', 'de', 'aklz', 'alsd fdsqkl', 'fdsqkl de', 'de aklz']

# %%
prepro('alsd fdsqkl de aklz')
# Out:
# 'alsd fdsqkl de aklz'

# %%
count_vect3.transform(['alsd fdsqkl de aklz'])
count_vect3.vocabulary_
# Out:
# {'djk': 9,
#  'dlsja': 11,
#  'ndskls': 18,
#  'fsjk': 15,
#  'djk dlsja': 10,
#  'dlsja ndskls': 12,
#  'ndskls fsjk': 19,
#  'fsjk de': 16,
#  'fsdklds': 13,
#  'zlzfio': 20,
#  'alksqn': 4,
#  'fsdklds zlzfio': 14,
#  'zlzfio de': 21,
#  'de alksqn': 7,
#  'ala': 2,
#  'apvsoijf': 5,
#  'aioa': 0,
#  'jaka': 17,
#  'ala apvsoijf': 3,
#  'apvsoijf aioa': 6,
#  'aioa de': 1,
#  'de jaka': 8}

# %%
count_vect4 = CountVectorizer(ngram_range=(1,2), strip_accents='unicode', stop_words=['de'])
count_vect4
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 2), preprocessor=None, stop_words=['de'],
#                 strip_accents='unicode', token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
count_vect4.fit(['djk dlsja ndskls fsjk de', 'fsdklds zlzfio de alksqn', 'ala apvsoijf aioa DE jaka'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 2), preprocessor=None, stop_words=['de'],
#                 strip_accents='unicode', token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
count_vect4.get_stop_words()
# Out:
# frozenset({'de'})

# %%
count_vect4.stop_words_
# Out:
# set()

# %%
token4 = count_vect4.build_tokenizer()
anal4 = count_vect4.build_analyzer()
prepro4 = count_vect4.build_preprocessor()

# %%
token4('alsd fdsqkl de aklz zksd, als')
# Out:
# ['alsd', 'fdsqkl', 'de', 'aklz', 'zksd', 'als']

# %%
anal4('alsd fdsqkl de aklz zksd, als')
# Out:
# ['alsd',
#  'fdsqkl',
#  'aklz',
#  'zksd',
#  'als',
#  'alsd fdsqkl',
#  'fdsqkl aklz',
#  'aklz zksd',
#  'zksd als']

# %%
prepro4('alsd fdsqkl de aklz zksd, als')
# Out:
# 'alsd fdsqkl de aklz zksd, als'
